# %% [markdown]
# # Video 4 Read Write CSV

# %%
import pandas as pd
# header= None(means no header in the file)
# names=["Teams", "Wins"], names of columns
# nrows=3, loads 3 rows from dataset
premier_stats = pd.read_csv("stats.csv", nrows=100)

# %%
premier_stats
# Out:
#                        team  wins  losses  goals  total_yel_card  \
# 0         Manchester United  28.0     5.0   83.0            60.0
# 1                   Chelsea  24.0     3.0   64.0            62.0
# 2                 Liverpool  20.0    10.0   57.0            44.0
# 3                   Arsenal  19.0     8.0   63.0            59.0
# 4         Tottenham Hotspur  17.0    12.0   57.0            48.0
# ..                      ...   ...     ...    ...             ...
# 95  Wolverhampton Wanderers  11.0    20.0   46.0            62.0
# 96                Blackpool  10.0    19.0   55.0            47.0
# 97           Wigan Athletic   9.0    14.0   40.0            67.0
# 98          Birmingham City   8.0    15.0   37.0            57.0
# 99          West Ham United   7.0    19.0   43.0            59.0
#
#     total_red_card  total_scoring_att  ontarget_scoring_att  hit_woodwork  \
# 0              1.0              698.0                 256.0          21.0
# ...

# %%
#save short stats into a new csv file
premier_stats.to_csv('new_stats.csv', columns=['team', 'goals', 'wins', 'losses', 'season'], header=False)
