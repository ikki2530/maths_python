# %% [markdown]
# # VIDEO 1 DATAFRAME BASICS

# %%
import pandas as pd
#creating the dataframe
premier_league = pd.read_csv("results.csv")
stats_premier = pd.read_csv("stats.csv")
premier_league
# Out:
#               home_team         away_team  home_goals  away_goals result  \
# 0      Sheffield United         Liverpool         1.0         1.0      D
# 1               Arsenal       Aston Villa         1.0         1.0      D
# 2               Everton           Watford         2.0         1.0      H
# 3      Newcastle United    Wigan Athletic         2.0         1.0      H
# 4            Portsmouth  Blackburn Rovers         3.0         0.0      H
# ...                 ...               ...         ...         ...    ...
# 4555   Newcastle United           Chelsea         3.0         0.0      H
# 4556        Southampton   Manchester City         0.0         1.0      A
# 4557       Swansea City        Stoke City         1.0         2.0      A
# 4558  Tottenham Hotspur    Leicester City         5.0         4.0      H
# 4559    West Ham United           Everton         3.0         1.0      H
#
#          season
# 0     2006-2007
# 1     2006-2007
# 2     2006-2007
# 3     2006-2007
# ...

# %%
premier_league.shape
# Out:
# (4560, 6)

# %%
stats_premier.shape
# Out:
# (240, 42)

# %%
#showing all columns
stats_premier.columns
# Out:
# Index(['team', 'wins', 'losses', 'goals', 'total_yel_card', 'total_red_card',
#        'total_scoring_att', 'ontarget_scoring_att', 'hit_woodwork',
#        'att_hd_goal', 'att_pen_goal', 'att_freekick_goal', 'att_ibox_goal',
#        'att_obox_goal', 'goal_fastbreak', 'total_offside', 'clean_sheet',
#        'goals_conceded', 'saves', 'outfielder_block', 'interception',
#        'total_tackle', 'last_man_tackle', 'total_clearance', 'head_clearance',
#        'own_goals', 'penalty_conceded', 'pen_goals_conceded', 'total_pass',
#        'total_through_ball', 'total_long_balls', 'backward_pass',
#        'total_cross', 'corner_taken', 'touches', 'big_chance_missed',
#        'clearance_off_line', 'dispossessed', 'penalty_save',
#        'total_high_claim', 'punches', 'season'],
#       dtype='object')

# %%
stats_premier.team #stats_premier['team']
# Out:
# 0         Manchester United
# 1                   Chelsea
# 2                 Liverpool
# 3                   Arsenal
# 4         Tottenham Hotspur
#                ...
# 235       Huddersfield Town
# 236            Swansea City
# 237             Southampton
# 238              Stoke City
# 239    West Bromwich Albion
# Name: team, Length: 240, dtype: object

# %%
type(stats_premier['team'])
# Out:
# pandas.core.series.Series

# %%
stats_premier[['team', 'wins', 'losses', 'season']] #showing more than 2 or more columns
# Out:
#                      team  wins  losses     season
# 0       Manchester United  28.0     5.0  2006-2007
# 1                 Chelsea  24.0     3.0  2006-2007
# 2               Liverpool  20.0    10.0  2006-2007
# 3                 Arsenal  19.0     8.0  2006-2007
# 4       Tottenham Hotspur  17.0    12.0  2006-2007
# ..                    ...   ...     ...        ...
# 235     Huddersfield Town   9.0    19.0  2017-2018
# 236          Swansea City   8.0    21.0  2017-2018
# 237           Southampton   7.0    16.0  2017-2018
# 238            Stoke City   7.0    19.0  2017-2018
# 239  West Bromwich Albion   6.0    19.0  2017-2018
#
# [240 rows x 4 columns]

# %%
stats_premier['goals'].std() #max value, mean(average), min(minimun value), std(standard deviation)
# Out:
# 16.203473786861455

# %%
stats_premier.describe() #some stats about columns
# Out:
#              wins      losses       goals  total_yel_card  total_red_card  \
# count  240.000000  240.000000  240.000000      240.000000      240.000000
# mean    14.150000   14.150000   51.062500       61.079167        2.862500
# std      6.022482    5.596846   16.203474       10.078249        1.802442
# min      1.000000    2.000000   20.000000       38.000000        0.000000
# 25%     10.000000   10.000000   40.000000       54.000000        1.000000
# 50%     12.000000   15.000000   47.000000       60.500000        3.000000
# 75%     18.000000   19.000000   61.000000       67.000000        4.000000
# max     32.000000   29.000000  106.000000       94.000000        9.000000
#
#        total_scoring_att  ontarget_scoring_att  hit_woodwork  att_hd_goal  \
# count         240.000000            240.000000    240.000000   240.000000
# mean          514.241667            168.116667     12.283333     9.016667
# std            95.979164             38.748882      4.820950     3.659077
# ...

# %% [markdown]
# ## Filters and conditions

# %%
stats_premier[stats_premier.goals > 75] #teams with more than 75 goals
# Out:
#                   team  wins  losses  goals  total_yel_card  total_red_card  \
# 0    Manchester United  28.0     5.0   83.0            60.0             1.0
# 20   Manchester United  27.0     5.0   80.0            51.0             2.0
# 42           Liverpool  25.0     2.0   77.0            50.0             0.0
# 60             Chelsea  27.0     6.0  103.0            54.0             5.0
# 61   Manchester United  27.0     7.0   86.0            49.0             4.0
# 62             Arsenal  23.0     9.0   83.0            56.0             1.0
# 80   Manchester United  23.0     4.0   78.0            56.0             3.0
# 100    Manchester City  28.0     5.0   93.0            51.0             5.0
# 101  Manchester United  28.0     5.0   89.0            51.0             1.0
# 120  Manchester United  28.0     5.0   86.0            57.0             1.0
# 140    Manchester City  27.0     6.0  102.0            72.0             1.0
# ...

# %%
stats_premier[stats_premier.total_yel_card > 55]
# Out:
#                      team  wins  losses  goals  total_yel_card  \
# 0       Manchester United  28.0     5.0   83.0            60.0
# 1                 Chelsea  24.0     3.0   64.0            62.0
# 3                 Arsenal  19.0     8.0   63.0            59.0
# 5        Bolton Wanderers  16.0    14.0   47.0            84.0
# 7        Blackburn Rovers  15.0    16.0   52.0            77.0
# ..                    ...   ...     ...    ...             ...
# 233       West Ham United  10.0    16.0   48.0            73.0
# 235     Huddersfield Town   9.0    19.0   28.0            62.0
# 237           Southampton   7.0    16.0   37.0            63.0
# 238            Stoke City   7.0    19.0   35.0            62.0
# 239  West Bromwich Albion   6.0    19.0   31.0            73.0
#
#      total_red_card  total_scoring_att  ontarget_scoring_att  hit_woodwork  \
# 0               1.0              698.0                 256.0          21.0
# ...

# %%
stats_premier[stats_premier.goals == stats_premier.goals.max()]
# Out:
#                 team  wins  losses  goals  total_yel_card  total_red_card  \
# 220  Manchester City  32.0     2.0  106.0            59.0             2.0
#
#      total_scoring_att  ontarget_scoring_att  hit_woodwork  att_hd_goal  ...  \
# 220              665.0                 265.0          23.0         12.0  ...
#
#      total_cross  corner_taken  touches  big_chance_missed  \
# 220        691.0         284.0  35130.0               63.0
#
#      clearance_off_line  dispossessed  penalty_save  total_high_claim  \
# 220                 4.0         406.0           2.0              21.0
#
#      punches     season
# 220     15.0  2017-2018
#
# [1 rows x 42 columns]

# %%
#showing some estra data for teams with more than 80 goals 
stats_premier[['season', 'team', 'goals', 'wins', 'losses']][stats_premier.goals > 80]
# Out:
#         season               team  goals  wins  losses
# 0    2006-2007  Manchester United   83.0  28.0     5.0
# 60   2009-2010            Chelsea  103.0  27.0     6.0
# 61   2009-2010  Manchester United   86.0  27.0     7.0
# 62   2009-2010            Arsenal   83.0  23.0     9.0
# 100  2011-2012    Manchester City   93.0  28.0     5.0
# 101  2011-2012  Manchester United   89.0  28.0     5.0
# 120  2012-2013  Manchester United   86.0  28.0     5.0
# 140  2013-2014    Manchester City  102.0  27.0     6.0
# 141  2013-2014          Liverpool  101.0  26.0     6.0
# 161  2014-2015    Manchester City   83.0  24.0     7.0
# 200  2016-2017            Chelsea   85.0  30.0     5.0
# 201  2016-2017  Tottenham Hotspur   86.0  26.0     4.0
# 220  2017-2018    Manchester City  106.0  32.0     2.0
# 224  2017-2018          Liverpool   84.0  21.0     5.0

# %%
stats_premier.set_index('team', inplace=True) #fixing team as the index

# %%
stats_premier.loc['Manchester United'] #show Manchester United results
# Out:
#                    wins  losses  goals  total_yel_card  total_red_card  \
# team
# Manchester United  28.0     5.0   83.0            60.0             1.0
# Manchester United  27.0     5.0   80.0            51.0             2.0
# Manchester United  28.0     4.0   68.0            61.0             5.0
# Manchester United  27.0     7.0   86.0            49.0             4.0
# Manchester United  23.0     4.0   78.0            56.0             3.0
# Manchester United  28.0     5.0   89.0            51.0             1.0
# Manchester United  28.0     5.0   86.0            57.0             1.0
# Manchester United  19.0    12.0   64.0            66.0             3.0
# Manchester United  20.0     8.0   62.0            64.0             5.0
# Manchester United  19.0    10.0   49.0            65.0             1.0
# Manchester United  18.0     5.0   54.0            78.0             2.0
# Manchester United  25.0     7.0   68.0            64.0             1.0
#
# ...

# %%
#stats_premier.reset_index(inplace=True) #reset the index

# %%
stats_premier.loc[["Manchester United", "Liverpool"]] # should be fixed 'teams' like index
# Out:
#                    wins  losses  goals  total_yel_card  total_red_card  \
# team
# Manchester United  28.0     5.0   83.0            60.0             1.0
# Manchester United  27.0     5.0   80.0            51.0             2.0
# Manchester United  28.0     4.0   68.0            61.0             5.0
# Manchester United  27.0     7.0   86.0            49.0             4.0
# Manchester United  23.0     4.0   78.0            56.0             3.0
# Manchester United  28.0     5.0   89.0            51.0             1.0
# Manchester United  28.0     5.0   86.0            57.0             1.0
# Manchester United  19.0    12.0   64.0            66.0             3.0
# Manchester United  20.0     8.0   62.0            64.0             5.0
# Manchester United  19.0    10.0   49.0            65.0             1.0
# Manchester United  18.0     5.0   54.0            78.0             2.0
# Manchester United  25.0     7.0   68.0            64.0             1.0
# ...
